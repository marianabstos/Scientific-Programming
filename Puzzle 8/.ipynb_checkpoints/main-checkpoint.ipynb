# %%
from BFS import BFS
from DFS import DFS
from SubidaEncosta import SubidaEncosta
from Aestrela import Aestrela
import time

# %%
len(bfs.getAcoes())
# Out:
# 747

# %%
len(dfs.getAcoes())
# Out:
# 1411

# %%
inicio = time.time()
bfs = BFS([4,1,6,3,2,8,7,0,5], [0,1,2,3,4,5,6,7,8])
bfs.buscaLargura()
fim = time.time()
print("BFS TEMPO EXECUÇÃO")
print(fim - inicio)
# Out:
# BFS TEMPO EXECUÇÃO
# 0.06981158256530762

# %%
inicio = time.time()
dfs = DFS([4,1,6,3,2,8,7,0,5], [0,1,2,3,4,5,6,7,8])
dfs.buscaProfundidade()
fim = time.time()
print("DFS TEMPO EXECUÇÃO")
print(fim - inicio)
# Out:
# Solução Encontrada
# ...

# %%
inicio = time.time()
h = SubidaEncosta([4,1,6,3,2,8,7,0,5], [0,1,2,3,4,5,6,7,8])
h.subidaEncosta()
fim = time.time()
print("HILL CLIMBING TEMPO EXECUÇÃO")
print(fim - inicio)
# Out:
# HILL CLIMBING TEMPO EXECUÇÃO
# 0.000997781753540039

# %%
inicio = time.time()
a = Aestrela([4,1,6,3,2,8,7,0,5], [0,1,2,3,4,5,6,7,8])
a.buscaAestrela()
fim = time.time()
print("A* TEMPO EXECUÇÃO")
print(fim - inicio)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b663e25b38b1> in <module>()
#       1 inicio = time.time()
#       2 h = Aestrela([4,1,6,3,2,8,7,0,5], [0,1,2,3,4,5,6,7,8])
# ----> 3 h.buscaAestrela()
#       4 fim = time.time()
#       5 print("A* TEMPO EXECUÇÃO")
#
# ~\Desktop\Códigos\Scientific-Programming\Puzzle 8\Aestrela.py in buscaAestrela(self)
#      30             for filho in g.getListaAdjacencia()[vertice]:
#      31                 heuristica[filho] = []
# ---> 32                 heuristica[filho].append((g.getCusto()[vertice] + g.getCusto()[filho]) + g.getCusto()[filho]*random())
#      33
#      34             verticeMenorCusto = min(heuristica, key=heuristica.get)
#
# KeyboardInterrupt:

# %%
a.getAcoes()
# Out:
# ['esquerda',
#  'direita',
#  'esquerda',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'abaixo',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'acima',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
#  'abaixo',
# ...
